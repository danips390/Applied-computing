# %% [markdown]
# # Análisis de resultados

# %%
import matplotlib.pyplot as plt
import pandas as pd

tweets_clean_classified = "balanceadoGOD.csv"
df_tweets_clean_fil = pd.read_csv(tweets_clean_classified)

tipo_counts = df_tweets_clean_fil['Tipo'].value_counts()

# Creación del histograma
tipo_counts.plot(kind='bar', color='skyblue')
plt.xlabel('Clasificación')
plt.ylabel('Frecuencia')
plt.title('Clasificaciones de los tweets')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Cargar el CSV
df = pd.read_csv('df_tweets_procesados_con_probabilidades.csv')


# Convertir la columna de fechas a tipo datetime, manejando errores
df['Fecha'] = pd.to_datetime(df['Fecha'], errors='coerce')

# Eliminar filas donde la fecha no es válida
df = df.dropna(subset=['Fecha'])

# Filtrar solo las fechas del año 2024
df_2024 = df[df['Fecha'].dt.year == 2024]

# Agrupar por fecha y calcular el puntaje promedio
promedio_puntaje = df_2024.groupby('Fecha')['Puntaje'].mean().reset_index()

# Crear la gráfica
plt.figure(figsize=(10, 6))
plt.plot(promedio_puntaje['Fecha'], promedio_puntaje['Puntaje'], marker='o', linestyle='-')
plt.title('Promedio de Puntaje por Fecha')
plt.xlabel('Fecha')
plt.ylabel('Puntaje Promedio')
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Cargar el CSV
df = pd.read_csv('df_tweets_procesados_con_probabilidades.csv')

# Convertir la columna de fechas a tipo datetime, manejando errores
df['Fecha'] = pd.to_datetime(df['Fecha'], errors='coerce')

# Eliminar filas donde la fecha no es válida
df = df.dropna(subset=['Fecha'])

# Filtrar solo las fechas del año 2024
df_2024 = df[df['Fecha'].dt.year == 2024]

# Agrupar por fecha y calcular el puntaje promedio
promedio_puntaje = df_2024.groupby('Fecha')['Puntaje'].mean().reset_index()

# Crear la gráfica
fig, ax1 = plt.subplots(figsize=(10, 6))

# Gráfico de líneas para el puntaje promedio
ax1.plot(promedio_puntaje['Fecha'], promedio_puntaje['Puntaje'], marker='o', linestyle='-', color='b')
ax1.set_title('Promedio de Puntaje por Fecha y Frecuencia')
ax1.set_xlabel('Fecha')
ax1.set_ylabel('Puntaje Promedio', color='b')
ax1.tick_params(axis='y', labelcolor='b')
ax1.set_xticks(promedio_puntaje['Fecha'][::5])  # Mostrar cada 5 fechas
ax1.set_xticklabels(promedio_puntaje['Fecha'].dt.strftime('%Y-%m-%d')[::5], rotation=45)

# Crear un segundo eje y para el histograma
ax2 = ax1.twinx()
ax2.hist(df_2024['Fecha'], bins=30, alpha=0.3, color='gray', edgecolor='black')
ax2.set_ylabel('Frecuencia', color='gray')
ax2.tick_params(axis='y', labelcolor='gray')

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Cargar el CSV
df = pd.read_csv('df_tweets_procesados_con_probabilidades.csv')

# Convertir la columna de fechas a tipo datetime, manejando errores
df['Fecha'] = pd.to_datetime(df['Fecha'], errors='coerce')

# Eliminar filas donde la fecha no es válida
df = df.dropna(subset=['Fecha'])

# Filtrar solo los datos del mes de junio de 2024
df_junio = df[(df['Fecha'].dt.year == 2024) & (df['Fecha'].dt.month == 6)]

# Crear el histograma de puntajes
plt.figure(figsize=(10, 6))
plt.hist(df_junio['Puntaje'], bins=20, color='skyblue', edgecolor='black')
plt.title('Histograma de Puntajes - Junio 2024')
plt.xlabel('Puntaje')
plt.ylabel('Frecuencia')
plt.grid(axis='y', alpha=0.75)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Cargar el CSV
df = pd.read_csv('df_tweets_procesados_con_probabilidades.csv')

# Convertir la columna de fechas a tipo datetime, manejando errores
df['Fecha'] = pd.to_datetime(df['Fecha'], errors='coerce')

# Eliminar filas donde la fecha no es válida
df = df.dropna(subset=['Fecha'])

# Filtrar solo los datos del mes de junio de 2024
df_junio = df[(df['Fecha'].dt.year == 2024) & (df['Fecha'].dt.month == 8)]

# Crear el histograma de puntajes
plt.figure(figsize=(10, 6))
plt.hist(df_junio['Puntaje'], bins=20, color='skyblue', edgecolor='black')
plt.title('Histograma de Puntajes - Agosto 2024')
plt.xlabel('Puntaje')
plt.ylabel('Frecuencia')
plt.grid(axis='y', alpha=0.75)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Cargar el CSV
df = pd.read_csv('df_tweets_procesados_con_probabilidades.csv')

# Convertir la columna de fechas a tipo datetime, manejando errores
df['Fecha'] = pd.to_datetime(df['Fecha'], errors='coerce')

# Eliminar filas donde la fecha no es válida
df = df.dropna(subset=['Fecha'])

# Redondear los valores de la columna 'Puntaje' al entero más cercano
df['Puntaje_redondeado'] = df['Puntaje'].round()

# Crear el histograma de los puntajes redondeados
plt.figure(figsize=(10, 6))
plt.hist(df['Puntaje_redondeado'], bins=5, color='skyblue', edgecolor='black')
plt.title('Histograma de Puntajes Redondeados')
plt.xlabel('Puntaje (redondeado)')
plt.ylabel('Frecuencia')
plt.grid(axis='y', alpha=0.75)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

tweets_clean_classified = 'checkpoint_filtrado.csv'
df_tweets_clean_fil = pd.read_csv(tweets_clean_classified)

tipo_counts = df_tweets_clean_fil['Tipo'].value_counts()

# Creación del histograma
tipo_counts.plot(kind='bar', color='skyblue')
plt.xlabel('Clasificación')
plt.ylabel('Frecuencia')
plt.title('Clasificaciones de los tweets')
plt.show()

# %% [markdown]
# Hacer web scraping de la página de la CFE para obtener el consumo energético por hogar en agebs

# %%
import pandas as pd
import geopandas as gpd
from geopy.geocoders import Nominatim
import time
from shapely.geometry import Point
import os
import json
import folium
import numpy as np
from matplotlib.colors import Normalize
from matplotlib import cm
# Out:
# /Users/Daniel/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
# Inicializar el geolocalizador
geolocator = Nominatim(user_agent="mi_aplicacion_mapa")
# Cargar los shapefiles
shapefile_municipios = "2023_1_19_A/2023_1_19_A.shp"
shapefile_colonias = "Colonias/Colonias.shp"
gdf_municipios = gpd.read_file(shapefile_municipios)
gdf_colonias = gpd.read_file(shapefile_colonias)
gdf_colonias = gdf_colonias[gdf_colonias["ST_NAME"] == "NUEVO LEON"]
# Cargar el archivo CSV
df_calles = pd.read_csv("Tweets_procesados_expo3.csv")
df_calles = df_calles[~df_calles['municipio'].isin(['monte morelos', 'saltillo'])]
df_calles['colonia'] = df_calles['colonia'].str.upper()

# Filtrar municipios y calcular puntaje promedio
cve_mun_values = {
    '006': 'apodaca',
    '019': 'san pedro garza garcía',
    '021': 'escobedo',
    '026': 'guadalupe',
    '039': 'monterrey',
    '046': 'san nicolás',
    '048': 'santa catarina',
    '049': 'santiago'
}
promedio_puntajes_municipios = {}
for cve, municipio in cve_mun_values.items():
    filas_municipio = df_calles[df_calles['municipio'].str.lower() == municipio.lower()]
    promedio_puntajes_municipios[cve] = np.mean(filas_municipio['Puntaje']) if not filas_municipio.empty else None

gdf_municipios['Puntaje'] = gdf_municipios['CVE_MUN'].map(promedio_puntajes_municipios)

# Crear el mapa con Folium
mapa = folium.Map(location=[25.6866, -100.3161], zoom_start=13)
municipios_layer = folium.FeatureGroup(name='Municipios')
colonias_layer = folium.FeatureGroup(name='Colonias')
calles_layer = folium.FeatureGroup(name='Calles')

# Añadir municipios al mapa
norm_municipios = Normalize(vmin=-2, vmax=2)
cmap_municipios = cm.get_cmap('RdYlGn')

for _, row in gdf_municipios.iterrows():
    puntaje = row['Puntaje']
    if puntaje is not None:
        color = cmap_municipios(norm_municipios(puntaje))[:3]
        color = [int(c * 255) for c in color]
        folium.GeoJson(
            row['geometry'],
            style_function=lambda x, color=color: {
                'fillColor': f'rgba({color[0]}, {color[1]}, {color[2]}, 0.6)',
                'color': 'black',
                'weight': 1,
                'fillOpacity': 0.6,
            }
        ).add_to(municipios_layer)

# Añadir colonias al mapa
gdf_colonias = gdf_colonias.merge(df_calles, left_on='SETT_NAME', right_on='colonia', how='left')
norm_colonias = Normalize(vmin=df_calles['Puntaje'].min(), vmax=df_calles['Puntaje'].max())
cmap_colonias = cm.get_cmap('RdYlGn')

for _, row in gdf_colonias.iterrows():
    puntaje = row['Puntaje']
    if puntaje is not None:
        color = cmap_colonias(norm_colonias(puntaje))[:3]
        color = [int(c * 255) for c in color]
        folium.GeoJson(
            row['geometry'],
            style_function=lambda x, color=color: {
                'fillColor': f'rgba({color[0]}, {color[1]}, {color[2]}, 0.6)',
                'color': 'black',
                'weight': 1,
                'fillOpacity': 0.4,
            }
        ).add_to(colonias_layer)

# Añadir capas al mapa
municipios_layer.add_to(mapa)
colonias_layer.add_to(mapa)
folium.LayerControl().add_to(mapa)

# Guardar archivos SHP
gdf_municipios.to_file('ArcGis/puntaje_municipios2.shp')
print("Shapefile de municipioc creado")
gdf_colonias.to_file('ArcGis/puntaje_colonias2.shp')
print("Shapefile de colonias creado")

# Archivo para guardar el último ID procesado
ultimo_id_file_path = "ultimo_id_procesado.json"

# Leer el último ID procesado desde el archivo, si existe
if os.path.exists(ultimo_id_file_path):
    with open(ultimo_id_file_path, 'r') as file:
        ultimo_id_procesado = json.load(file).get('ultimo_id', 0)
else:
    ultimo_id_procesado = 0

# Filtrar el DataFrame para obtener solo las filas con ID mayor al último procesado
df_nuevas_filas = df_calles[df_calles['ID'] > ultimo_id_procesado]

# Si hay nuevas filas para procesar
if not df_nuevas_filas.empty:
    municipios_lista = ['Monterrey', 'Apodaca', 'San Pedro Garza García', 'Escobedo', 'Guadalupe', 'San Nicolás', 'Santa Catarina', 'Santiago']
    datos_geo = []

    for idx, row in df_nuevas_filas.iterrows():
        calles_lista = row['calle']
        puntaje = row['Puntaje']  # Obtener el puntaje de la calle
        tipo = row['Tipo']  # Obtener la clasificación de la calle

        # Asegurarse de que el valor de 'calle' es una cadena
        if isinstance(calles_lista, str):
            calles_lista = [calle.strip() for calle in calles_lista.split(',')]

        # Iterar sobre las calles de la fila
        if isinstance(calles_lista, list) and calles_lista:
            for calle in calles_lista:
                if calle and "[]" not in calle:  # Asegurarse de que la calle no esté vacía
                    found_location = False
                    for municipio in municipios_lista:
                        try:
                            # Intentar geolocalizar la calle
                            location = geolocator.geocode(calle + ", " + municipio + ", Mexico")
                            time.sleep(1)  # Evitar sobrecarga del servicio
                            if location:
                                # Guardar los datos geográficos
                                datos_geo.append({
                                    'calle': calle,
                                    'puntaje': puntaje,
                                    'tipo': tipo,
                                    'geometry': Point(location.longitude, location.latitude)
                                })
                                found_location = True
                                print(f"Se obtuvieron las coordenadas para {calle} en {municipio}")
                                break
                        except Exception as e:
                            print(f"Error al intentar obtener las coordenadas para {calle} en {municipio}: {e}")
                    
                    if not found_location:
                        print(f"No se encontraron coordenadas para {calle} en ningún municipio.")
    
    # Convertir los datos de calles nuevas a GeoDataFrame
    gdf_nuevas_calles = gpd.GeoDataFrame(datos_geo, geometry='geometry')
    gdf_nuevas_calles.set_crs(epsg=4326, inplace=True)

    # Verificar si ya existe el archivo SHP anterior
    shp_file_path = 'ArcGis/puntaje_calles2.shp'
    
    if os.path.exists(shp_file_path):
        # Si ya existe, cargar los datos antiguos y anexar las nuevas filas
        gdf_calles_existente = gpd.read_file(shp_file_path)
        gdf_calles_actualizado = pd.concat([gdf_calles_existente, gdf_nuevas_calles], ignore_index=True)
    else:
        # Si no existe, simplemente usar las nuevas filas
        gdf_calles_actualizado = gdf_nuevas_calles

    # Guardar el archivo SHP actualizado con los datos anteriores y los nuevos
    gdf_calles_actualizado.to_file(shp_file_path)
    print("Shapefile de calles creado")

   # Actualizar el último ID procesado
    nuevo_ultimo_id = int(df_nuevas_filas['ID'].max())
    try:
        with open(ultimo_id_file_path, 'w') as file:
            json.dump({'ultimo_id': nuevo_ultimo_id}, file)
            file.flush()  # Asegura que los datos se envíen al disco inmediatamente
    except Exception as e:
        print(f"Error al escribir el archivo JSON: {e}")

else:
    print("No hay nuevas filas para procesar.")


# Guardar el mapa en un archivo HTML
mapa.save("mapa_interactivo.html")
# Out:
# /var/folders/8b/d34q145x44x2xf_06_gchyfw0000gq/T/ipykernel_45101/2312694498.py:40: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap_municipios = cm.get_cmap('RdYlGn')
# /var/folders/8b/d34q145x44x2xf_06_gchyfw0000gq/T/ipykernel_45101/2312694498.py:60: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap_colonias = cm.get_cmap('RdYlGn')
# Shapefile de municipioc creado
# /var/folders/8b/d34q145x44x2xf_06_gchyfw0000gq/T/ipykernel_45101/2312694498.py:85: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   gdf_colonias.to_file('ArcGis/puntaje_colonias2.shp')
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Cargar el dataset
df = pd.read_csv("Tweets_procesados_expo3.csv")

# Contar las publicaciones de cada usuario
top_usuarios = df['Usuario'].value_counts().nlargest(10)

# Crear el histograma
plt.figure(figsize=(10, 6))
top_usuarios.plot(kind='bar', color='skyblue')
plt.title("Top 10 Usuarios con más publicaciones")
plt.xlabel("Usuario")
plt.ylabel("Número de publicaciones")
plt.xticks(rotation=45)
plt.show()

# %%
# Obtener la lista de nombres de los 10 usuarios con más publicaciones
lista_top_usuarios = top_usuarios.index.tolist()
print(lista_top_usuarios)
# Out:
# ['@Cicmty', '@elnortelocal', '@GobSanNicolas', '@ABCNoticiasMX', '@cesarmty', '@saz2000', '@911SanPedro', '@conagua_mx', '@LCAlatorre', '@PC_NuevoLeon']

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Cargar el CSV en un DataFrame
df = pd.read_csv("Tweets_procesados_expo3.csv")

# Contar las frecuencias por calle y tipo
frecuencias_calle_tipo = df.groupby(['calle', 'Tipo']).size().unstack(fill_value=0)

# Filtrar las calles con frecuencia mayor o igual a 5
frecuencias_calle_tipo = frecuencias_calle_tipo.loc[frecuencias_calle_tipo.sum(axis=1) >= 5]

# Ordenar por la frecuencia total y seleccionar el top 15
frecuencias_calle_tipo = frecuencias_calle_tipo.loc[frecuencias_calle_tipo.sum(axis=1).sort_values(ascending=True).index[:15]]

# Crear un gráfico de barras apiladas horizontal para las calles filtradas y ordenadas
frecuencias_calle_tipo.plot(kind='barh', stacked=True, figsize=(10, 8), colormap='viridis')

# Añadir etiquetas y título
plt.title('Top 15 calles más nombradas y su problemática', fontsize=16)
plt.xlabel('Frecuencia', fontsize=12)
plt.ylabel('Calle', fontsize=12)

# Ajustar el gráfico
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Cargar el CSV en un DataFrame
df = pd.read_csv("Tweets_procesados_expo3.csv")

# Separar las calles múltiples en registros individuales
df = df.assign(calle=df['calle'].str.split(',')).explode('calle')

# Eliminar espacios en blanco adicionales
df['calle'] = df['calle'].str.strip()

# Contar las frecuencias por calle y tipo
frecuencias_calle_tipo = df.groupby(['calle', 'Tipo']).size().unstack(fill_value=0)

# Filtrar las calles con frecuencia mayor o igual a 5
frecuencias_calle_tipo = frecuencias_calle_tipo.loc[frecuencias_calle_tipo.sum(axis=1) >= 5]

# Ordenar por la frecuencia total en orden descendente y seleccionar el top 15
frecuencias_calle_tipo = frecuencias_calle_tipo.loc[frecuencias_calle_tipo.sum(axis=1).sort_values(ascending=False).index[:15]]

# Crear un gráfico de barras apiladas horizontal para las calles filtradas y ordenadas
frecuencias_calle_tipo.plot(kind='barh', stacked=True, figsize=(10, 8), colormap='viridis')

# Invertir el orden de las barras para que el top esté arriba
plt.gca().invert_yaxis()

# Añadir etiquetas y título
plt.title('Top 15 calles más nombradas y su problemática', fontsize=16)
plt.xlabel('Frecuencia', fontsize=12)
plt.ylabel('Calle', fontsize=12)

# Ajustar el gráfico
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Cargar el CSV en un DataFrame
df = pd.read_csv("Tweets_procesados_expo3.csv")

# Separar las calles múltiples en registros individuales
df = df.assign(calle=df['calle'].str.split(',')).explode('calle')

# Eliminar espacios en blanco adicionales
df['calle'] = df['calle'].str.strip()

# Contar las frecuencias por calle y tipo
frecuencias_calle_tipo = df.groupby(['colonia', 'Tipo']).size().unstack(fill_value=0)

# Filtrar las calles con frecuencia mayor o igual a 5
frecuencias_calle_tipo = frecuencias_calle_tipo.loc[frecuencias_calle_tipo.sum(axis=1) >= 5]

# Ordenar por la frecuencia total en orden descendente y seleccionar el top 15
frecuencias_calle_tipo = frecuencias_calle_tipo.loc[frecuencias_calle_tipo.sum(axis=1).sort_values(ascending=False).index[:15]]

# Crear un gráfico de barras apiladas horizontal para las calles filtradas y ordenadas
frecuencias_calle_tipo.plot(kind='barh', stacked=True, figsize=(10, 8), colormap='viridis')

# Invertir el orden de las barras para que el top esté arriba
plt.gca().invert_yaxis()

# Añadir etiquetas y título
plt.title('Top 15 calles más nombradas y su problemática', fontsize=16)
plt.xlabel('Frecuencia', fontsize=12)
plt.ylabel('Calle', fontsize=12)

# Ajustar el gráfico
plt.tight_layout()
plt.show()

# %%
import pandas as pd

# Cargar los tres archivos CSV en DataFrames
csv1 = pd.read_csv('Tweets_Sep05_2022_1.csv')
csv2 = pd.read_csv('Tweets_Sep05_2022_2.csv')
csv3 = pd.read_csv('Tweets_Sep05_2022_3.csv')

# Concatenar los tres DataFrames en uno solo
df_unido = pd.concat([csv1, csv2, csv3])

# Guardar el DataFrame unido en un nuevo archivo CSV
df_unido.to_csv('Tweets_Sep05_2022.csv', index=False)

print("Los archivos CSV han sido unidos")
# Out:
# Los archivos CSV han sido unidos

# %% [markdown]
# # Nuevos Tweets

# %%
import matplotlib.pyplot as plt
import pandas as pd

tweets_clean_classified = 'Tweets_2017_2024_SENTIMIENTO.csv'
df_tweets_clean_fil = pd.read_csv(tweets_clean_classified)

tipo_counts = df_tweets_clean_fil['Tipo'].value_counts()

# Creación del histograma
tipo_counts.plot(kind='bar', color='skyblue')
plt.xlabel('Clasificación')
plt.ylabel('Frecuencia')
plt.title('Clasificaciones de los tweets')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# Cargar el CSV
df = pd.read_csv('Tweets_2017_2024_SENTIMIENTO.csv')
df['Fecha'] = pd.to_datetime(df['Fecha'], errors='coerce')
df = df.dropna(subset=['Fecha'])

años = sorted(df['Fecha'].dt.year.unique())

for año in años:
    df_año = df[df['Fecha'].dt.year == año]
    promedio_puntaje = df_año.groupby('Fecha')['Puntaje'].mean().reset_index()

    fig, ax1 = plt.subplots(figsize=(12, 6))

    # Scatter para evitar líneas en saltos grandes
    ax1.scatter(promedio_puntaje['Fecha'], promedio_puntaje['Puntaje'], color='blue')
    ax1.set_title(f'Promedio de Puntaje y Frecuencia por Fecha - {año}')
    ax1.set_xlabel('Fecha')
    ax1.set_ylabel('Puntaje Promedio', color='blue')
    ax1.tick_params(axis='y', labelcolor='blue')

    # Formato de fecha automático y legible
    ax1.xaxis.set_major_locator(mdates.AutoDateLocator())
    ax1.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
    fig.autofmt_xdate(rotation=45)

    ax2 = ax1.twinx()
    ax2.hist(df_año['Fecha'], bins=30, alpha=0.3, color='gray', edgecolor='black')
    ax2.set_ylabel('Frecuencia', color='gray')
    ax2.tick_params(axis='y', labelcolor='gray')

    plt.tight_layout()
    plt.show()

# %% [markdown]
# El número de tweets general es proporcional al nivel de lluvia y luego hacer zoom.
# Demostrar que el evento genera un incremento

# %%
df1= pd.read_csv("concatenados_tweets.csv")
df1.head()
# Out:
#        Usuario              Nombre                      Fecha  \
# 0  SSP_Apodaca  Policía de Apodaca  2020-09-13 00:35:07+00:00
# 1  SSP_Apodaca  Policía de Apodaca  2020-09-10 17:39:18+00:00
# 2  SSP_Apodaca  Policía de Apodaca  2020-09-10 17:24:53+00:00
# 3  SSP_Apodaca  Policía de Apodaca  2020-09-10 01:40:46+00:00
# 4  SSP_Apodaca  Policía de Apodaca  2020-09-09 18:13:51+00:00
#
#                                                Texto  Likes  Retweets  \
# 0           cayiskayis apodacaoficial cc pfnuevoleon      1         0
# 1  se logró la detención de una persona por amena...     13         3
# 2  aviso vecinos de la col los fresnos por corte ...      8         0
# 3  inicia la lluvia en diferentes sectores de apo...     33        19
# 4  se logró la detención de dos personas por port...     16         5
#
#    Comentarios  Citas             Tipo   Puntaje
# 0            1      0  no se relaciona -0.021045
# 1            0      0           crimen -0.167202
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd

tweets_clean_classified = 'concatenados_tweets.csv'
df_tweets_clean_fil = pd.read_csv(tweets_clean_classified)

tipo_counts = df_tweets_clean_fil['Tipo'].value_counts()

# Creación del histograma
tipo_counts.plot(kind='bar', color='skyblue')
plt.xlabel('Clasificación')
plt.ylabel('Frecuencia')
plt.title('Clasificaciones de los tweets')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

tweets_clean_classified = 'prueba_glob.csv'
df_tweets_clean_fil = pd.read_csv(tweets_clean_classified)

tipo_counts = df_tweets_clean_fil['Tipo'].value_counts()

# Creación del histograma
tipo_counts.plot(kind='bar', color='skyblue')
plt.xlabel('Clasificación')
plt.ylabel('Frecuencia')
plt.title('Clasificaciones de los tweets')
plt.show()

# %%
df_glob= pd.read_csv('tweets_concatenados_fecha_corregida.csv')

# Convertir la columna de fecha a tipo datetime
df_glob["Fecha"] = pd.to_datetime(df_glob["Fecha"])

# Extraer solo la fecha (sin hora) para contar ocurrencias por día
df_glob["solo_fecha"] = df_glob["Fecha"].dt.date

# Contar la frecuencia de cada fecha
fecha_counts = df_glob["solo_fecha"].value_counts().sort_index()

# Graficar la distribución de fechas usando un histograma
plt.figure(figsize=(12, 6))
plt.hist(df_glob["Fecha"], bins=30, color="skyblue", edgecolor="black")
plt.xlabel("Fecha")
plt.ylabel("Frecuencia")
plt.title("Distribución de Fechas en el Dataset")
plt.xticks(rotation=45)
plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.show()

# %%
df_glob= pd.read_csv('tweets_concatenados_globales.csv')
df_sin_duplicados = df_glob.drop_duplicates(subset="Texto")
df_sin_duplicados.to_csv('tweets_concatenados_GLOB.csv', index=False)

# %% [markdown]
# # Analizando tweets_concatenados_final_limpio

# %%
df_glob= pd.read_csv('tweets_concatenados_final_limpio.csv')
df_sin_duplicados = df_glob.drop_duplicates(subset="Texto")
df_sin_duplicados.to_csv('tweets_concatenados_GLOBALES.csv', index=False)
df_sin_duplicados
# Out:
#               Usuario                Nombre                      Fecha  \
# 0         SSP_Apodaca    Policía de Apodaca  2020-09-13 00:35:07+00:00
# 1         SSP_Apodaca    Policía de Apodaca  2020-09-10 17:39:18+00:00
# 2         SSP_Apodaca    Policía de Apodaca  2020-09-10 17:24:53+00:00
# 3         SSP_Apodaca    Policía de Apodaca  2020-09-10 01:40:46+00:00
# 4         SSP_Apodaca    Policía de Apodaca  2020-09-09 18:13:51+00:00
# ...               ...                   ...                        ...
# 13092  @ayd_monterrey    Agua y Drenaje Mty                        NaN
# 13093  @ayd_monterrey    Agua y Drenaje Mty                        NaN
# 13094  @ayd_monterrey    Agua y Drenaje Mty                        NaN
# 13095  @ayd_monterrey    Agua y Drenaje Mty                        NaN
# 13101   @joluisgarcia  JosÃ© Luis GarcÃ­a C                        NaN
#
#                                                    Texto  Likes  Retweets  \
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd
df_glob= pd.read_csv('tweets_concatenados_GLOBALES.csv')
tipo_counts = df_glob['Tipo'].value_counts()

# Creación del histograma
tipo_counts.plot(kind='bar', color='skyblue')
plt.xlabel('Clasificación')
plt.ylabel('Frecuencia')
plt.title('Clasificaciones de los tweets')
plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Cargar el archivo
df = pd.read_csv("tweets_concatenados_GLOBALES.csv")

# Filtrar tweets con categorías válidas (excluyendo "no se relaciona")
df_filtrado = df[df["Tipo"] != "no se relaciona"]

# Contar tweets por categoría
conteo_categorias = df_filtrado["Tipo"].value_counts()

# Crear gráfico de barras
plt.figure(figsize=(10, 6))
conteo_categorias.plot(kind='bar', color='skyblue', edgecolor='black')
plt.title("Distribución de Tweets por Categoría (excluyendo 'no se relaciona')")
plt.xlabel("Categoría")
plt.ylabel("Cantidad de Tweets")
plt.xticks(rotation=45)
plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Cargar el DataFrame
df = pd.read_csv("tweets_concatenados_GLOBALES.csv")

# Asegurar que la columna Fecha esté en formato datetime
df["Fecha"] = pd.to_datetime(df["Fecha"], errors="coerce")

# Filtrar textos con categoría distinta de "no se relaciona"
df_categorizado = df[df["Tipo"] != "QUESO"].copy()

# Agrupar por mes
df_categorizado["Mes"] = df_categorizado["Fecha"].dt.to_period("M")

# Contar frecuencia por mes
frecuencia_mensual = df_categorizado["Mes"].value_counts().sort_index()

# Filtrar solo los meses con más de 20 tweets
frecuencia_filtrada = frecuencia_mensual[frecuencia_mensual > 5]

# Graficar histograma
plt.figure(figsize=(12, 6))
frecuencia_filtrada.plot(kind='bar', color='skyblue', edgecolor='black')
plt.title("Cantidad de Tweets por Mes")
plt.xlabel("Mes")
plt.ylabel("Cantidad de Tweets")
plt.xticks(rotation=45)
plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
# /var/folders/8b/d34q145x44x2xf_06_gchyfw0000gq/T/ipykernel_29925/1494177544.py:14: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   df_categorizado["Mes"] = df_categorizado["Fecha"].dt.to_period("M")

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Cargar el archivo
df = pd.read_csv("tweets_concatenados_GLOBALES.csv")

# Asegurar formato datetime para la columna Fecha
df["Fecha"] = pd.to_datetime(df["Fecha"], errors="coerce")

# Filtrar tweets con categorías válidas (excluyendo "no se relaciona")
df_categorizado = df[df["Tipo"] != "no se relaciona"].copy()

# Crear columna de periodo mensual
df_categorizado["Mes"] = df_categorizado["Fecha"].dt.to_period("M")

# Agrupar por mes y tipo, contar ocurrencias
pivot_mensual = df_categorizado.groupby(["Mes", "Tipo"]).size().unstack(fill_value=0)

# Filtrar meses con más de 20 tweets en total
pivot_mensual = pivot_mensual[pivot_mensual.sum(axis=1) > 20]

# Graficar stack plot
plt.figure(figsize=(14, 7))
plt.stackplot(pivot_mensual.index.to_timestamp(), pivot_mensual.T.values, labels=pivot_mensual.columns)
plt.title("Evolución Mensual de Tweets por Categoría")
plt.xlabel("Mes")
plt.ylabel("Cantidad de Tweets")
plt.legend(loc="upper left")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# /var/folders/8b/d34q145x44x2xf_06_gchyfw0000gq/T/ipykernel_29925/908485250.py:14: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   df_categorizado["Mes"] = df_categorizado["Fecha"].dt.to_period("M")

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Cargar el archivo
df = pd.read_csv("tweets_concatenados_GLOBALES.csv")

# Asegurar formato datetime para la columna Fecha
df["Fecha"] = pd.to_datetime(df["Fecha"], errors="coerce")

# Filtrar tweets con categorías válidas (excluyendo "no se relaciona")
df_categorizado = df[df["Tipo"] != "no se relaciona"].copy()

# Crear columna de periodo mensual
df_categorizado["Mes"] = df_categorizado["Fecha"].dt.to_period("M")

# Calcular puntaje promedio por mes y categoría
pivot_mensual_puntaje = df_categorizado.groupby(["Mes", "Tipo"])["Puntaje"].mean().unstack(fill_value=0)

# Filtrar meses con más de 20 tweets (según cantidad, no puntaje)
conteo_mensual = df_categorizado.groupby("Mes").size()
meses_validos = conteo_mensual[conteo_mensual > 20].index
pivot_mensual_puntaje = pivot_mensual_puntaje.loc[meses_validos]

# Graficar stack plot de puntaje promedio
plt.figure(figsize=(14, 7))
plt.stackplot(
    pivot_mensual_puntaje.index.to_timestamp(),
    pivot_mensual_puntaje.T.values,
    labels=pivot_mensual_puntaje.columns
)
plt.title("Evolución del Puntaje Promedio por Categoría (Mensual)")
plt.xlabel("Mes")
plt.ylabel("Puntaje Promedio")
plt.legend(loc="upper left")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# /var/folders/8b/d34q145x44x2xf_06_gchyfw0000gq/T/ipykernel_29925/2771243918.py:14: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   df_categorizado["Mes"] = df_categorizado["Fecha"].dt.to_period("M")
